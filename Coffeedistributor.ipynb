# %% [markdown]
# # The city of choice for Coffee

# %% [markdown]
# ## Introduction
#
# A friend of mine is looking to open a coffee roastery in Canada and wants to know which city between Toronto, Montreal and Vancouver would be the best to start the business. For this we will evaluate the number of coffee shops that are available in these cities. The logic is that the more coffee shops are available the more opportunities would be available to sell the roasted coffee beans. This would mean a larger target group and probably a higher revenue. The target audience is the friend who wants to open his business and ensure that he has enough prospective customers. He should get a list of which customers he could provide coffee beans to and why a specific city would be best.

# %% [markdown]
# ## Data
#
# We will primarily use __foursquare__ as the basis for our data. After importing the necessary libraries we will extract the location of the cities in terms of latitude and longitude. This will be done via __geopy__. The locations will enable us to search for coffee shops in the vicinity of the city centre. The radius in which the search will be done is chosen as __5km__. This data will be extracted from the __foursquare__ database. We will then implement the results of all cities in one __dataframe__. To check that the coffee shops are in the correct area we will show the positions on a __folium__ map. This will be the basis for the evaluation. This data will still have to be looked into for consistency and relevance and thus might have to be cleaned in the evaluation stage.

# %% [markdown]
# ### Import necessary Libraries
#
# To fulfil the task we will need the following libraries.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

from sklearn.cluster import KMeans #module for clustering
from sklearn.preprocessing import StandardScaler # module for preprocessing for the cluster analysis

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

import matplotlib.cm as cm # module for visualisation
import matplotlib.colors as colors #module for visualisation
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'BW1GHF0SUKO0Y2DZIQYSB4DU3IHXNEIXHN1FVYYCE2O5OYVO' # your Foursquare ID
CLIENT_SECRET = 'HGIW0BQTPFA3QZFTA1DQQRZI5WAWVYREJZSX1JC53EA4MYZN' # your Foursquare Secret
ACCESS_TOKEN = '4SEVI1EPK1YGKIQUVPHPDS3BNVIQ41E3XFATR4MLM2OAFELT' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BW1GHF0SUKO0Y2DZIQYSB4DU3IHXNEIXHN1FVYYCE2O5OYVO
# CLIENT_SECRET:HGIW0BQTPFA3QZFTA1DQQRZI5WAWVYREJZSX1JC53EA4MYZN

# %% [markdown]
# #### First of all we will need the location of the different cities. For this we will get the different locations of the cities. For each city we will define the latittude and longitude. The locations are printed as an output.

# %%
VAN_address = 'Vancouver, BC'
TOR_address = 'Toronto, ON'
MON_address = 'Montreal, QC'
# Location of Vancouver
geolocator = Nominatim(user_agent="VAN_agent")
VAN_location = geolocator.geocode(VAN_address)
VAN_latitude = VAN_location.latitude
VAN_longitude = VAN_location.longitude
#Location of Toronto
geolocator = Nominatim(user_agent="TOR_agent")
TOR_location = geolocator.geocode(TOR_address)
TOR_latitude = TOR_location.latitude
TOR_longitude = TOR_location.longitude
#Location of Montreal
geolocator = Nominatim(user_agent="MON_agent")
MON_location = geolocator.geocode(MON_address)
MON_latitude = MON_location.latitude
MON_longitude = MON_location.longitude



print('Location of Vancouver', VAN_latitude , VAN_longitude)
print('Location of Toronto', TOR_latitude, TOR_longitude)
print('Location of Montreal', MON_latitude, MON_longitude)
# Out:
# Location of Vancouver 49.2608724 -123.1139529
# Location of Toronto 43.6534817 -79.3839347
# Location of Montreal 45.4972159 -73.6103642

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for coffee shops in a radius of 5kms from the centres of the cities

# %% [markdown]
# #### To have the same prerequisites for each city we will assume that the same search radius should give the same chances for each city. The radius is set as 5km.

# %%
search_query = 'Coffee Shop'
radius = 5000

# %% [markdown]
# #### For the different cities we will define an URL each

# %%
url_VAN = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VAN_latitude, VAN_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url_TOR = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, TOR_latitude, TOR_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url_MON = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, MON_latitude, MON_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results_VAN = requests.get(url_VAN).json()
results_TOR = requests.get(url_TOR).json()
results_MON = requests.get(url_MON).json()

# %% [markdown]
# #### Get relevant part of JSON and transform it into a _pandas_ dataframe

# %%
# assign relevant part of JSON to venues
venues_VAN = results_VAN['response']['venues']
venues_TOR = results_TOR['response']['venues']
venues_MON = results_MON['response']['venues']
# tranform venues into a dataframe
df_VAN = json_normalize(venues_VAN)
df_TOR = json_normalize(venues_TOR)
df_MON = json_normalize(venues_MON)
df_MON.tail()
# Out:
# <ipython-input-8-02958583a0f8>:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_VAN = json_normalize(venues_VAN)
# <ipython-input-8-02958583a0f8>:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_TOR = json_normalize(venues_TOR)
# <ipython-input-8-02958583a0f8>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_MON = json_normalize(venues_MON)
#                           id           name  \
# 45  5b84fca2c0af57002ca69274     Sushi Shop
# 46  5a590e4c0a464d6ac47a5982  Dumpling Shop
# 47  4cacabc6965c9c74802dccfa     Sushi Shop
# 48  4b1d4ca9f964a520690e24e3  The Body Shop
# 49  4c0fbcc3c6cf76b021c38251     Sushi Shop
#
#                                            categories    referralId  hasPerk  \
# 45  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1625002763    False
# 46  [{'id': '4bf58dd8d48988d108941735', 'name': 'D...  v-1625002763    False
# 47  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1625002763    False
# 48  [{'id': '4bf58dd8d48988d10c951735', 'name': 'C...  v-1625002763    False
# 49  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1625002763    False
#
#     location.lat  location.lng  \
# 45     45.473220    -73.600918
# 46     45.474707    -73.623587
# 47     45.501355    -73.570814
# 48     45.502824    -73.571933
# 49     45.475696    -73.622347
#
#                               location.labeledLatLngs  location.distance  \
# 45  [{'label': 'display', 'lat': 45.47322, 'lng': ...               2771
# 46  [{'label': 'display', 'lat': 45.474707, 'lng':...               2709
# 47  [{'label': 'display', 'lat': 45.501355, 'lng':...               3120
# 48  [{'label': 'display', 'lat': 45.502824, 'lng':...               3062
# 49  [{'label': 'display', 'lat': 45.475696, 'lng':...               2571
#
#    location.cc location.city location.state location.country  \
# 45          CA      Montréal             QC           Canada
# 46          CA      Montréal             QC           Canada
# 47          CA      Montréal             QC           Canada
# 48          CA      Montréal             QC           Canada
# 49          CA      Montréal             QC           Canada
#
#                             location.formattedAddress  \
# 45   [1001 Boul Decarie, Montréal QC H4A 3J1, Canada]
# 46  [5674 Av de Monkland, Montréal QC H4A 1E4, Can...
# 47  [1200 Ave McGill College (coin Cathcart), Mont...
# 48         [4 Place Ville Marie, Montréal QC, Canada]
# 49  [5580 Av Monkland (Marcil), Montréal QC H4A 1C...
#
#            location.address location.postalCode location.crossStreet  \
# 45        1001 Boul Decarie             H4A 3J1                  NaN
# 46      5674 Av de Monkland             H4A 1E4                  NaN
# 47  1200 Ave McGill College             H3B 4G7        coin Cathcart
# 48      4 Place Ville Marie                 NaN                  NaN
# 49         5580 Av Monkland             H4A 1C9               Marcil
#
#    venuePage.id
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN

# %% [markdown]
# To have everything nice and visible in one dataframe we will concatenate these together

# %%
frames = [df_VAN, df_TOR, df_MON]
df_complete = pd.concat(frames)
df_complete.shape
# Out:
# (150, 19)

# %% [markdown]
# #### Define information of interest and filter dataframe.
# Now the data is filtered according to the categories.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_complete.columns if col.startswith('location.')] + ['id']
df = df_complete.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df['categories'] = df.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df.columns = [column.split('.')[-1] for column in df.columns]

df
# Out:
#                            name           categories  \
# 0           Laura's Coffee Shop                Diner
# 1            7 Days Coffee Shop                 Café
# 2   The Taste & See Coffee Shop          Coffee Shop
# 3      Delicatessen Coffee Shop       Sandwich Place
# 4         Eclettico Coffee Shop                 Café
# ..                          ...                  ...
# 45                   Sushi Shop           Restaurant
# 46                Dumpling Shop  Dumpling Restaurant
# 47                   Sushi Shop           Restaurant
# 48                The Body Shop       Cosmetics Shop
# 49                   Sushi Shop           Restaurant
#
#                       address       crossStreet        lat         lng  \
# 0           1945 Manitoba St.       at 4th Ave.  49.267427 -123.106913
# 1              920 Beatty St.               NaN  49.275102 -123.117491
# 2   1628 West 1st Avenue #128               NaN  49.270256 -123.141433
# 3                         NaN  Davie at Burrard  49.278508 -123.129527
# 4                         NaN               NaN  49.247820 -123.089950
# ..                        ...               ...        ...         ...
# 45          1001 Boul Decarie               NaN  45.473220  -73.600918
# 46        5674 Av de Monkland               NaN  45.474707  -73.623587
# 47    1200 Ave McGill College     coin Cathcart  45.501355  -73.570814
# 48        4 Place Ville Marie               NaN  45.502824  -73.571933
# 49           5580 Av Monkland            Marcil  45.475696  -73.622347
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 49.267427, 'lng':...       891    V5Y 3A1
# 1   [{'label': 'display', 'lat': 49.275102, 'lng':...      1604        NaN
# 2   [{'label': 'display', 'lat': 49.270256, 'lng':...      2252        NaN
# 3   [{'label': 'display', 'lat': 49.27850795147412...      2265        NaN
# 4   [{'label': 'display', 'lat': 49.24782, 'lng': ...      2269    V5V 4E8
# ..                                                ...       ...        ...
# 45  [{'label': 'display', 'lat': 45.47322, 'lng': ...      2771    H4A 3J1
# 46  [{'label': 'display', 'lat': 45.474707, 'lng':...      2709    H4A 1E4
# 47  [{'label': 'display', 'lat': 45.501355, 'lng':...      3120    H3B 4G7
# 48  [{'label': 'display', 'lat': 45.502824, 'lng':...      3062        NaN
# 49  [{'label': 'display', 'lat': 45.475696, 'lng':...      2571    H4A 1C9
#
#     cc       city state country  \
# 0   CA  Vancouver    BC  Canada
# 1   CA        NaN   NaN  Canada
# 2   CA  Vancouver    BC  Canada
# 3   CA  Vancouver    BC  Canada
# 4   CA  Vancouver    BC  Canada
# ..  ..        ...   ...     ...
# 45  CA   Montréal    QC  Canada
# 46  CA   Montréal    QC  Canada
# 47  CA   Montréal    QC  Canada
# 48  CA   Montréal    QC  Canada
# 49  CA   Montréal    QC  Canada
#
#                                      formattedAddress neighborhood  \
# 0   [1945 Manitoba St. (at 4th Ave.), Vancouver BC...          NaN
# 1                            [920 Beatty St., Canada]          NaN
# 2   [1628 West 1st Avenue #128, Vancouver BC, Canada]          NaN
# 3            [Davie at Burrard, Vancouver BC, Canada]          NaN
# 4                      [Vancouver BC V5V 4E8, Canada]          NaN
# ..                                                ...          ...
# 45   [1001 Boul Decarie, Montréal QC H4A 3J1, Canada]          NaN
# 46  [5674 Av de Monkland, Montréal QC H4A 1E4, Can...          NaN
# 47  [1200 Ave McGill College (coin Cathcart), Mont...          NaN
# 48         [4 Place Ville Marie, Montréal QC, Canada]          NaN
# 49  [5580 Av Monkland (Marcil), Montréal QC H4A 1C...          NaN
#
#                           id
# 0   4c48639e417b20a19bbfe0a9
# 1   57196f28498e2aeaefab44b2
# 2   586453fa0037eb3be739c864
# 3   4eda85d546907c1b42d3711e
# 4   5cca5b711fa763002ca67636
# ..                       ...
# 45  5b84fca2c0af57002ca69274
# 46  5a590e4c0a464d6ac47a5982
# 47  4cacabc6965c9c74802dccfa
# 48  4b1d4ca9f964a520690e24e3
# 49  4c0fbcc3c6cf76b021c38251
#
# [150 rows x 16 columns]

# %% [markdown]
# #### Looking at the data it seems like there are also a lot of restaurants, sushi places, etc. that have been added. We would however be only looking for pure coffee shops. Thus we will have to clean the dataframe and remove everything that is not a coffee shop or café

# %% [markdown]
# #### Let's visualize the Coffee Shops that are in the cities. This only shows the data not yet an evaluation.

# %%
df.name
# Out:
# 0             Laura's Coffee Shop
# 1              7 Days Coffee Shop
# 2     The Taste & See Coffee Shop
# 3        Delicatessen Coffee Shop
# 4           Eclettico Coffee Shop
#                  ...
# 45                     Sushi Shop
# 46                  Dumpling Shop
# 47                     Sushi Shop
# 48                  The Body Shop
# 49                     Sushi Shop
# Name: name, Length: 150, dtype: object

# %%
venues_map = folium.Map(location=[TOR_latitude, TOR_longitude], zoom_start=3) # generate map centred aroun Toronto

# add a red circle marker to represent the different cities
folium.CircleMarker(
    [TOR_latitude, TOR_longitude],
    radius=10,
    color='red',
    popup='Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

folium.CircleMarker(
    [VAN_latitude, VAN_longitude],
    radius=10,
    color='red',
    popup='Vancouver',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

folium.CircleMarker(
    [MON_latitude, MON_longitude],
    radius=10,
    color='red',
    popup='Montreal',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Coffee shops as blue circle markers
for lat, lng, label in zip(df.lat, df.lng, df.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_85ffecd0d40a4f3d87f83b5d1634b244%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_85ffecd0d40a4f3d87f83b5d1634b244%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_85ffecd0d40a4f3d87f83b5d1634b244%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_85ffecd0d40a4f3d87f83b5d1634b244%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# # Methodology
#
# With this data we will have a look at which city as the highest density of coffee shops. First of all we will filter for pure coffee shops or similar. This means that no restaurants, sushi places, etc. will be included in the dataframe.
#
# After cleaning the data we will analyze the amount of coffee shops near the centre of the city using a folium map. A simple map showing the amount will suffice in showing which city has the highest density. This will lead to the city selection.
#
# Considering that the coffee has to be distributed we will go one step further and cluster the city into n amounts. For the cluster we will consider that per week each coffee shop has to receive fresh coffee once. The coffee is distributed via bike and 8 coffee shops can be supplied per day as a first estimate. The clusters should show the area the bike has to supply.

# %% [markdown]
# # Analysis
#
# As we saw in the earlier description of the dataframe we will need to concentrate on the coffee shops. Everything that is a restaurant, sushi place or similar is not what is needed by the customer and will thus be removed from the dataframe. This we do with the following code.

# %%
df_coffee= df[df["name"].str.contains("Coffee|Café")==True]
df_coffee
# Out:
#                                      name             categories  \
# 0                     Laura's Coffee Shop                  Diner
# 1                      7 Days Coffee Shop                   Café
# 2             The Taste & See Coffee Shop            Coffee Shop
# 3                Delicatessen Coffee Shop         Sandwich Place
# 4                   Eclettico Coffee Shop                   Café
# ..                                    ...                    ...
# 1                        Solo Coffee Shop                   Café
# 2                       Vortex CoffeeShop            Coffee Shop
# 3                            Coffee Depot                   Café
# 4                      Coffee machine BBR  Corporate Coffee Shop
# 38  White Heron Coffee (Café Héron Blanc)            Coffee Shop
#
#                           address       crossStreet        lat         lng  \
# 0               1945 Manitoba St.       at 4th Ave.  49.267427 -123.106913
# 1                  920 Beatty St.               NaN  49.275102 -123.117491
# 2       1628 West 1st Avenue #128               NaN  49.270256 -123.141433
# 3                             NaN  Davie at Burrard  49.278508 -123.129527
# 4                             NaN               NaN  49.247820 -123.089950
# ..                            ...               ...        ...         ...
# 1   65 Sherbrooke Est, bureau 110               NaN  45.514187  -73.568269
# 2          40, rue Jean-Talon Est               NaN  45.534908  -73.617304
# 3                             NaN               NaN  45.502210  -73.566780
# 4    606, rue Cathcart, 10e étage               NaN  45.503467  -73.568119
# 38      131 rue Prince-Arthur Est               NaN  45.515212  -73.571554
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 49.267427, 'lng':...       891    V5Y 3A1
# 1   [{'label': 'display', 'lat': 49.275102, 'lng':...      1604        NaN
# 2   [{'label': 'display', 'lat': 49.270256, 'lng':...      2252        NaN
# 3   [{'label': 'display', 'lat': 49.27850795147412...      2265        NaN
# 4   [{'label': 'display', 'lat': 49.24782, 'lng': ...      2269    V5V 4E8
# ..                                                ...       ...        ...
# 1   [{'label': 'display', 'lat': 45.51418721002326...      3788    H2X 1C4
# 2   [{'label': 'display', 'lat': 45.53490842878835...      4230    H2R 1S3
# 3   [{'label': 'display', 'lat': 45.50221, 'lng': ...      3445    H3B 3C1
# 4   [{'label': 'display', 'lat': 45.503467, 'lng':...      3368        NaN
# 38  [{'label': 'display', 'lat': 45.515212, 'lng':...      3630    H3S 1B6
#
#     cc       city state country  \
# 0   CA  Vancouver    BC  Canada
# 1   CA        NaN   NaN  Canada
# 2   CA  Vancouver    BC  Canada
# 3   CA  Vancouver    BC  Canada
# 4   CA  Vancouver    BC  Canada
# ..  ..        ...   ...     ...
# 1   CA   Montréal    QC  Canada
# 2   CA   Montréal    QC  Canada
# 3   CA   Montréal    QC  Canada
# 4   CA   Montréal    QC  Canada
# 38  CA   Montréal    QC  Canada
#
#                                      formattedAddress neighborhood  \
# 0   [1945 Manitoba St. (at 4th Ave.), Vancouver BC...          NaN
# 1                            [920 Beatty St., Canada]          NaN
# 2   [1628 West 1st Avenue #128, Vancouver BC, Canada]          NaN
# 3            [Davie at Burrard, Vancouver BC, Canada]          NaN
# 4                      [Vancouver BC V5V 4E8, Canada]          NaN
# ..                                                ...          ...
# 1   [65 Sherbrooke Est, bureau 110, Montréal QC H2...          NaN
# 2   [40, rue Jean-Talon Est, Montréal QC H2R 1S3, ...          NaN
# 3                       [Montréal QC H3B 3C1, Canada]          NaN
# 4   [606, rue Cathcart, 10e étage, Montréal QC, Ca...          NaN
# 38  [131 rue Prince-Arthur Est, Montréal QC H3S 1B...          NaN
#
#                           id
# 0   4c48639e417b20a19bbfe0a9
# 1   57196f28498e2aeaefab44b2
# 2   586453fa0037eb3be739c864
# 3   4eda85d546907c1b42d3711e
# 4   5cca5b711fa763002ca67636
# ..                       ...
# 1   4d99d98c647d8cfae217113e
# 2   4d371c62e4b4a093ea2c2a36
# 3   5783d19b498e6150d6db1420
# 4   587f8a91fad9dc66ac900157
# 38  5df7d5cbc02d880007f4899e
#
# [81 rows x 16 columns]

# %% [markdown]
# This seems to be a bit more focused on the coffee aspect. Now we will create a marker map to easily see which city has the most potential customers. The amount of coffee shops in the central part (radius 5km) of the city will be our focus. For this we will use a folium map where the marker bubbles will show the amount of coffee shops.

# %%
from folium import plugins
from folium.plugins import MarkerCluster

map_canada = folium.Map(location=[TOR_latitude, TOR_longitude], zoom_start=3)

# instantiate a mark cluster object for the incidents in the dataframe
shops = MarkerCluster().add_to(map_canada)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_coffee.lat, df_coffee.lng, df_coffee.name):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(shops)

# display map
map_canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a20b9d4a0268484ea3669f5c3d3eb36c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a20b9d4a0268484ea3669f5c3d3eb36c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# We have to zoom in to see that Vancouver has the most coffee shops in a radius of 5km closely followed by Toronto and Montreal having only a third the amount in downtown. With this information we will focus on Toronto. The next step is to cluster the city into different areas, to allow for a normalized distribution of the coffee. Considering that the aim is to deliver the coffee by bike, we will need an even distribution in area. This means we will cluster the coffee shops into areas and not into the amount of coffee shops. Thus the area will be the same not the amount of coffee shops. These clusters are then the delivery areas for a specific day of the week. First we will create a dataset that only inlcudes the Toronto coffeeshops.

# %%
df_coffeeVAN= df_coffee[df_coffee["city"].str.contains("Vancouver")==True]
df_coffeeVAN
# Out:
#                                         name        categories  \
# 0                        Laura's Coffee Shop             Diner
# 2                The Taste & See Coffee Shop       Coffee Shop
# 3                   Delicatessen Coffee Shop    Sandwich Place
# 4                      Eclettico Coffee Shop              Café
# 5            Mama and Papa Cuban Coffee Shop  Cuban Restaurant
# 6                            The Coffee Shop              Café
# 7                     Y57 Coffee Shop Series       Music Venue
# 8                      Cultured Coffee & Tea       Coffee Shop
# 9                               Blenz Coffee       Coffee Shop
# 10                            Elysian Coffee       Coffee Shop
# 12                            WFM Coffee Bar       Coffee Shop
# 13                      Kafka’s Coffee & Tea       Coffee Shop
# 16                              Blenz Coffee       Coffee Shop
# 17                        Waves Coffee House       Coffee Shop
# 18                            Coo Coo Coffee              Café
# 21                            Elysian Coffee       Coffee Shop
# 22                       Aperture Coffee Bar       Coffee Shop
# 23                             Milano Coffee       Coffee Shop
# 24                  Honolulu Coffee Broadway       Coffee Shop
# 25                              Blenz Coffee       Coffee Shop
# 26                              Blenz Coffee       Coffee Shop
# 27                             Tony's Coffee              Café
# 28  Bubble Tea; Ice Cream, Coffee & Desserts  Asian Restaurant
# 29                Finch’s Tea & Coffee House    Sandwich Place
# 31                              Blenz Coffee       Coffee Shop
# 32                       Aperture Coffee Bar       Coffee Shop
# 33                 Foglifter Coffee Roasters       Coffee Shop
# 35                              Blenz Coffee       Coffee Shop
# 36                            Elysian Coffee       Coffee Shop
# 37                        Waves Coffee House       Coffee Shop
# 38                      Trees Organic Coffee              Café
# 40                              Blenz Coffee       Coffee Shop
# 41         Darryl's Coffee & Native Art Shop              Café
# 44                   Iktsuarpok Coffee Stand       Coffee Shop
# 45                    Murchie’s Tea & Coffee          Tea Room
# 48                  Rocanini Coffee Roasters       Coffee Shop
# 49                        Waves Coffee House       Coffee Shop
#
#                       address                                  crossStreet  \
# 0           1945 Manitoba St.                                  at 4th Ave.
# 2   1628 West 1st Avenue #128                                          NaN
# 3                         NaN                             Davie at Burrard
# 4                         NaN                                          NaN
# 5                         NaN                                          NaN
# 6              2305 West 41st                                          NaN
# 7        2610 West 4th Avenue                                          NaN
# 8              555 W 12th Ave  at Cambie St in City Square Shopping Centre
# 9           521 West Broadway                                 at Cambie St
# 10            2301 Ontario St                                   at 7th Ave
# 12              510 W 8th Ave                                          NaN
# 13               2525 Main St                                  at Broadway
# 16            97 West 2nd Ave           West 2nd Avenue At Manitoba Street
# 17         1095 West Broadway                                 at Spruce St
# 18              477 Davie St.                              at Richards St.
# 21          590 West Broadway                                    at Ash St
# 22             243 W Broadway                                at Alberta St
# 23              156 W 8th Ave                  btwn Columbia & Manitoba St
# 24          548 West Broadway                                Cambia Street
# 25          695 West Broadway                               at Heather St.
# 26        338 Helmcken Street                              at Hamilton St.
# 27          805 west broadway                                       Willow
# 28          112 West Broadway                              Manitoba Street
# 29            353 W Pender St                                  at Homer St
# 31          2502 Maple Street                                   W Broadway
# 32               4124 Main St                         at E King Edward Ave
# 33               3590 Main St                                   E 20th Ave
# 35   508 West Hastings Street                              at Richards St.
# 36             1778 W 5th Ave                                at Burrard St
# 37          492 W Hastings St                               at Richards St
# 38          450 Granville St.             btwn W. Hastings & W. Pender St.
# 40           495 West Georgia                               at Richards St
# 41               945 Davie St                                      Burrard
# 44      30-425 Carrall Street                                          NaN
# 45          815 W Hastings St                           btwn Hornby & Howe
# 48              863 Beatty St                         btwn Robson & Smithe
# 49          100 - 900 Howe St                                 at Smithe St
#
#           lat         lng                                     labeledLatLngs  \
# 0   49.267427 -123.106913  [{'label': 'display', 'lat': 49.267427, 'lng':...
# 2   49.270256 -123.141433  [{'label': 'display', 'lat': 49.270256, 'lng':...
# 3   49.278508 -123.129527  [{'label': 'display', 'lat': 49.27850795147412...
# 4   49.247820 -123.089950  [{'label': 'display', 'lat': 49.24782, 'lng': ...
# 5   49.281197 -123.095818  [{'label': 'display', 'lat': 49.28119659423828...
# 6   49.234648 -123.159866  [{'label': 'display', 'lat': 49.234648, 'lng':...
# 7   49.268323 -123.164560  [{'label': 'display', 'lat': 49.26832260906662...
# 8   49.260936 -123.116359  [{'label': 'display', 'lat': 49.26093629933292...
# 9   49.263438 -123.115765  [{'label': 'display', 'lat': 49.26343759196383...
# 10  49.264621 -123.104963  [{'label': 'display', 'lat': 49.26462056353454...
# 12  49.263864 -123.115086  [{'label': 'display', 'lat': 49.26386375950810...
# 13  49.262418 -123.101178  [{'label': 'display', 'lat': 49.26241774940661...
# 16  49.269418 -123.106395  [{'label': 'display', 'lat': 49.26941767960925...
# 17  49.263595 -123.128825  [{'label': 'display', 'lat': 49.26359512424659...
# 18  49.275703 -123.123917  [{'label': 'display', 'lat': 49.27570349314551...
# 21  49.263168 -123.117331  [{'label': 'display', 'lat': 49.263168, 'lng':...
# 22  49.263252 -123.110438  [{'label': 'display', 'lat': 49.26325210516326...
# 23  49.263790 -123.108800  [{'label': 'display', 'lat': 49.26379, 'lng': ...
# 24  49.263060 -123.116700  [{'label': 'display', 'lat': 49.26306, 'lng': ...
# 25  49.263453 -123.119716  [{'label': 'display', 'lat': 49.26345334521473...
# 26  49.275936 -123.121126  [{'label': 'display', 'lat': 49.27593593925417...
# 27  49.263683 -123.122159  [{'label': 'display', 'lat': 49.26368264196417...
# 28  49.263173 -123.112638  [{'label': 'display', 'lat': 49.26317306401103...
# 29  49.282724 -123.111941  [{'label': 'display', 'lat': 49.28272404338896...
# 31  49.263600 -123.150339  [{'label': 'display', 'lat': 49.26360037531403...
# 32  49.248477 -123.100951  [{'label': 'display', 'lat': 49.24847719965427...
# 33  49.253071 -123.100705  [{'label': 'display', 'lat': 49.253071, 'lng':...
# 35  49.284030 -123.112030  [{'label': 'display', 'lat': 49.28402976929854...
# 36  49.267229 -123.145127  [{'label': 'display', 'lat': 49.26722928231353...
# 37  49.284003 -123.111956  [{'label': 'display', 'lat': 49.28400287508824...
# 38  49.284925 -123.114467  [{'label': 'display', 'lat': 49.28492513095138...
# 40  49.281144 -123.115973  [{'label': 'display', 'lat': 49.281144112765, ...
# 41  49.279035 -123.128430  [{'label': 'display', 'lat': 49.279035, 'lng':...
# 44  49.283613 -123.103997  [{'label': 'display', 'lat': 49.283613, 'lng':...
# 45  49.285575 -123.116164  [{'label': 'display', 'lat': 49.28557527023807...
# 48  49.276900 -123.115005  [{'label': 'display', 'lat': 49.27690024042664...
# 49  49.280793 -123.122699  [{'label': 'display', 'lat': 49.28079271339729...
#
#     distance postalCode  cc       city state country  \
# 0        891    V5Y 3A1  CA  Vancouver    BC  Canada
# 2       2252        NaN  CA  Vancouver    BC  Canada
# 3       2265        NaN  CA  Vancouver    BC  Canada
# 4       2269    V5V 4E8  CA  Vancouver    BC  Canada
# 5       2617        NaN  CA  Vancouver    BC  Canada
# 6       4433        V6m  CA  Vancouver    BC  Canada
# 7       3768        NaN  CA  Vancouver    BC  Canada
# 8        174    V5Z 3X7  CA  Vancouver    BC  Canada
# 9        314    V5Z 1E6  CA  Vancouver    BC  Canada
# 10       775    V5T 2X5  CA  Vancouver    BC  Canada
# 12       343    V5Z 1C5  CA  Vancouver    BC  Canada
# 13       943    V5T 3E5  CA  Vancouver    BC  Canada
# 16      1098    V5Y 1B1  CA  Vancouver    BC  Canada
# 17      1122    V6H 0A8  CA  Vancouver    BC  Canada
# 18      1802    V6B 2G2  CA  Vancouver    BC  Canada
# 21       354    V5Z 1E9  CA  Vancouver    BC  Canada
# 22       367    V5Y 3L1  CA  Vancouver    BC  Canada
# 23       495    V5Y 1N2  CA  Vancouver    BC  Canada
# 24       314    V5Z 1E9  CA  Vancouver    BC  Canada
# 25       507    V5Z 1G6  CA  Vancouver    BC  Canada
# 26      1755    V6B 6C5  CA  Vancouver    BC  Canada
# 27       673        NaN  CA  Vancouver    BC  Canada
# 28       273        NaN  CA  Vancouver    BC  Canada
# 29      2436    V6B 1T3  CA  Vancouver    BC  Canada
# 31      2660    V6J 1Z2  CA  Vancouver    BC  Canada
# 32      1672    V5V 3P7  CA  Vancouver    BC  Canada
# 33      1296    V5V 3N3  CA  Vancouver    BC  Canada
# 35      2581    V6B 1L6  CA  Vancouver    BC  Canada
# 36      2372    V6J 1P1  CA  Vancouver    BC  Canada
# 37      2578    V6B 1K6  CA  Vancouver    BC  Canada
# 38      2677    V6C 1V4  CA  Vancouver    BC  Canada
# 40      2261    V6B 1B3  CA  Vancouver    BC  Canada
# 41      2278        NaN  CA  Vancouver    BC  Canada
# 44      2632    V6A 1B2  CA  Vancouver    BC  Canada
# 45      2754    V6C 1K6  CA  Vancouver    BC  Canada
# 48      1785    V6B 2M6  CA  Vancouver    BC  Canada
# 49      2306    V6Z 2M4  CA  Vancouver    BC  Canada
#
#                                      formattedAddress  neighborhood  \
# 0   [1945 Manitoba St. (at 4th Ave.), Vancouver BC...           NaN
# 2   [1628 West 1st Avenue #128, Vancouver BC, Canada]           NaN
# 3            [Davie at Burrard, Vancouver BC, Canada]           NaN
# 4                      [Vancouver BC V5V 4E8, Canada]           NaN
# 5                              [Vancouver BC, Canada]           NaN
# 6          [2305 West 41st, Vancouver BC V6m, Canada]           NaN
# 7        [2610 West 4th Avenue, Vancouver BC, Canada]           NaN
# 8   [555 W 12th Ave (at Cambie St in City Square S...           NaN
# 9   [521 West Broadway (at Cambie St), Vancouver B...           NaN
# 10  [2301 Ontario St (at 7th Ave), Vancouver BC V5...           NaN
# 12      [510 W 8th Ave, Vancouver BC V5Z 1C5, Canada]           NaN
# 13  [2525 Main St (at Broadway), Vancouver BC V5T ...           NaN
# 16  [97 West 2nd Ave (West 2nd Avenue At Manitoba ...           NaN
# 17  [1095 West Broadway (at Spruce St), Vancouver ...           NaN
# 18  [477 Davie St. (at Richards St.), Vancouver BC...           NaN
# 21  [590 West Broadway (at Ash St), Vancouver BC V...           NaN
# 22  [243 W Broadway (at Alberta St), Vancouver BC ...           NaN
# 23  [156 W 8th Ave (btwn Columbia & Manitoba St), ...  Mt. Pleasant
# 24  [548 West Broadway (Cambia Street), Vancouver ...      Fairview
# 25  [695 West Broadway (at Heather St.), Vancouver...           NaN
# 26  [338 Helmcken Street (at Hamilton St.), Vancou...           NaN
# 27  [805 west broadway (Willow), Vancouver BC, Can...           NaN
# 28  [112 West Broadway (Manitoba Street), Vancouve...           NaN
# 29  [353 W Pender St (at Homer St), Vancouver BC V...           NaN
# 31  [2502 Maple Street (W Broadway), Vancouver BC ...           NaN
# 32  [4124 Main St (at E King Edward Ave), Vancouve...           NaN
# 33  [3590 Main St (E 20th Ave), Vancouver BC V5V 3...           NaN
# 35  [508 West Hastings Street (at Richards St.), V...           NaN
# 36  [1778 W 5th Ave (at Burrard St), Vancouver BC ...           NaN
# 37  [492 W Hastings St (at Richards St), Vancouver...           NaN
# 38  [450 Granville St. (btwn W. Hastings & W. Pend...           NaN
# 40  [495 West Georgia (at Richards St), Vancouver ...           NaN
# 41     [945 Davie St (Burrard), Vancouver BC, Canada]           NaN
# 44  [30-425 Carrall Street, Vancouver BC V6A 1B2, ...           NaN
# 45  [815 W Hastings St (btwn Hornby & Howe), Vanco...           NaN
# 48  [863 Beatty St (btwn Robson & Smithe), Vancouv...           NaN
# 49  [100 - 900 Howe St (at Smithe St), Vancouver B...           NaN
#
#                           id
# 0   4c48639e417b20a19bbfe0a9
# 2   586453fa0037eb3be739c864
# 3   4eda85d546907c1b42d3711e
# 4   5cca5b711fa763002ca67636
# 5   53da9e06498e61b428ee9a31
# 6   4c213b4d99282d7fde4865b0
# 7   4eea7ca08b81bff6aa21cde9
# 8   4be48099910020a134ced114
# 9   4aa8320cf964a520f94f20e3
# 10  5478ca03498e3bbc45e6ce54
# 12  54b2b74b498ee334f9cb197e
# 13  4c303a7d3ffc9521f4c28ff5
# 16  51f0591a498e26b88854db2f
# 17  4b049664f964a520665522e3
# 18  4aaa9910f964a520875620e3
# 21  4aa98676f964a520105420e3
# 22  5177156c498ea4fd6b901dda
# 23  4aec909ff964a520ccc821e3
# 24  59d50c08805e3f31de6461bc
# 25  4aee5795f964a520a0d321e3
# 26  4aa740d2f964a5207b4c20e3
# 27  4bdc66ab3904a59393014e9e
# 28  5092d71ae4b076702b4f1f56
# 29  4aa73d64f964a520734c20e3
# 31  4b282e0af964a520589024e3
# 32  59dcfcc46f706a3090eebc38
# 33  60d252f642acf41e65d791a5
# 35  4aabc53bf964a520045a20e3
# 36  4ab5587cf964a520147420e3
# 37  4ab00196f964a520816520e3
# 38  4aa75811f964a520bd4c20e3
# 40  4b17f803f964a52083ca23e3
# 41  4b02f004f964a520324b22e3
# 44  5c26cc7512c8f0002c96ee5b
# 45  4aa97329f964a520b55320e3
# 48  55032d19498eefc0748c452f
# 49  4b169b7bf964a520d8ba23e3

# %% [markdown]
# Now we will only focus on the positional data and remove all the columns that are not necessary. Then we will normalize this data to use it for the clustering method.

# %%
df_positiononly=df_coffeeVAN.drop(columns=['name', 'categories', 'address', 'crossStreet',
       'labeledLatLngs', 'distance', 'postalCode', 'cc', 'city', 'state',
       'country', 'formattedAddress', 'neighborhood', 'id'])
X = df_positiononly.values[:,1:]
X = np.nan_to_num(X)
cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset
# Out:
# array([[ 0.70343385],
#        [-1.41824867],
#        [-0.68648686],
#        [ 1.74602078],
#        [ 1.38538602],
#        [-2.55118534],
#        [-2.8396655 ],
#        [ 0.12286536],
#        [ 0.1593774 ],
#        [ 0.82331051],
#        [ 0.20113119],
#        [ 1.05591473],
#        [ 0.73529661],
#        [-0.64330179],
#        [-0.34165104],
#        [ 0.06311843],
#        [ 0.48675615],
#        [ 0.58745428],
#        [ 0.10190121],
#        [-0.08345408],
#        [-0.17012162],
#        [-0.23363702],
#        [ 0.3515349 ],
#        [ 0.39443074],
#        [-1.96560407],
#        [ 1.06988504],
#        [ 1.08499252],
#        [ 0.38895877],
#        [-1.64527623],
#        [ 0.39348255],
#        [ 0.23913101],
#        [ 0.14655482],
#        [-0.6190529 ],
#        [ 0.88265825],
#        [ 0.13485104],
#        [ 0.20607476],
#        [-0.26683579]])

# %% [markdown]
# According to the assumption above we will need 5 clusters (for each day of the week).

# %%
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cluster_dataset)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 1, 4, 2, 2, 3, 3, 0, 0, 2], dtype=int32)

# %% [markdown]
# Now we visualize the data of the coffee shops that are closest together to show what areas could be delivered to in one day. For this we add a cluster label to the dataframe to allow for visualisation. Furthermore the name of the coffee shop is added as a label for identification. With this the distribution could start.

# %%
df_visual=df_coffeeVAN
df_visual.insert(0, 'Cluster Labels', kmeans.labels_)
df_visual


# create map
map_clusters = folium.Map(location=[VAN_latitude, VAN_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_visual['lat'], df_visual['lng'], df_visual['name'], df_visual['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_950992bb99b14194950b93d726839a9d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_950992bb99b14194950b93d726839a9d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_950992bb99b14194950b93d726839a9d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_950992bb99b14194950b93d726839a9d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.2608724%2C%20-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Results and Discussion

# %% [markdown]
# The final map shows how the coffee could be distributed in the city of Toronto. Toronto was chosen as the basis for the coffee roastery as it had the greatest density of coffee shops in a 5km radius of the city centre compared to the cities Vancouver and Montreal. From the analysis this would have the highest chance of succeeding as the assumption is that the higher amount of coffee shops the higher the amount of potential for the need of coffee beans from a coffee roastery.
#
# The analysis does however have a few weaknesses in that a few points have to be evaluated in greater detail. The coffee shops that were evaluated are form a single database and maybe not all coffee shops were captured. For this other databases should be evaluated as well. A point that has to be considered is that Montreal shows far less coffee shops in comparison to the other two cities. The reasons for this should be looked to into as well and maybe the location of the city centre moved to find an area where the coffee shop density is higher.
#
# THe analysis focussed on three cities in Canada. It could be possible that further cities might have a higher density of coffee shops. This would however have to be discussed if a different city is an option.
#
# Furthermore it should be noted that the coffee shops probably already have there own coffee roastery distributor that supplies the coffee beans. This is difficult to evaluate but a first step would be to look into what coffee shops are part of a franchise and how many coffee roasteries are in the general area.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The analysis gave a first insight into which city is most probable to have a good customer base for a coffee roastery. Further analysis should be done to see where the coffee roastery could be physically based, i.e. in the city centre or further outside the city. This would have a large effect on the running costs.
#
# As the names of the coffee shops are available a survey should be done to see if there is a need for a different supplier of coffee beans. This is the proposed next step in finding the acceptance by the potential customers
