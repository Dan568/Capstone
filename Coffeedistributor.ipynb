# %% [markdown]
# # The city of choice for Coffee

# %% [markdown]
# ## Introduction
#
# A friend of mine is looking to open a coffee roastery in Canada and wants to know which city between Toronto, Montreal and Vancouver would be the best to start the business. For this we will evaluate the number of coffee shops that are available in these cities. The logic is that the more coffee shops are available the more opportunities would be available to sell the roasted coffee beans. This would mean a larger target group and probably a higher revenue. The target audience is the friend who wants to open his business and ensure that he has enough prospective customers. He should get a list of which customers he could provide coffee beans to and why a specific city would be best.

# %% [markdown]
# ## Data
#
# We will primarily use __foursquare__ as the basis for our data. After importing the necessary libraries we will extract the location of the cities in terms of latitude and longitude. This will be done via __geopy__. The locations will enable us to search for coffee shops in the vicinity of the city centre. The radius in which the search will be done is chosen as __5km__. This data will be extracted from the __foursquare__ database. We will then implement the results of all cities in one __dataframe__. To check that the coffee shops are in the correct area we will show the positions on a __folium__ map. This will be the basis for the evaluation. This data will still have to be looked into for consistency and relevance and thus might have to be cleaned in the evaluation stage.

# %% [markdown]
# ### Import necessary Libraries
#
# To fulfil the task we will need the following libraries.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

from sklearn.cluster import KMeans #module for clustering
from sklearn.preprocessing import StandardScaler # module for preprocessing for the cluster analysis

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

import matplotlib.cm as cm # module for visualisation
import matplotlib.colors as colors #module for visualisation
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'BW1GHF0SUKO0Y2DZIQYSB4DU3IHXNEIXHN1FVYYCE2O5OYVO' # your Foursquare ID
CLIENT_SECRET = 'HGIW0BQTPFA3QZFTA1DQQRZI5WAWVYREJZSX1JC53EA4MYZN' # your Foursquare Secret
ACCESS_TOKEN = '4SEVI1EPK1YGKIQUVPHPDS3BNVIQ41E3XFATR4MLM2OAFELT' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BW1GHF0SUKO0Y2DZIQYSB4DU3IHXNEIXHN1FVYYCE2O5OYVO
# CLIENT_SECRET:HGIW0BQTPFA3QZFTA1DQQRZI5WAWVYREJZSX1JC53EA4MYZN

# %% [markdown]
# #### First of all we will need the location of the different cities. For this we will get the different locations of the cities. For each city we will define the latittude and longitude. The locations are printed as an output.

# %%
VAN_address = 'Vancouver, BC'
TOR_address = 'Toronto, ON'
MON_address = 'Montreal, QC'
# Location of Vancouver
geolocator = Nominatim(user_agent="VAN_agent")
VAN_location = geolocator.geocode(VAN_address)
VAN_latitude = VAN_location.latitude
VAN_longitude = VAN_location.longitude
#Location of Toronto
geolocator = Nominatim(user_agent="TOR_agent")
TOR_location = geolocator.geocode(TOR_address)
TOR_latitude = TOR_location.latitude
TOR_longitude = TOR_location.longitude
#Location of Montreal
geolocator = Nominatim(user_agent="MON_agent")
MON_location = geolocator.geocode(MON_address)
MON_latitude = MON_location.latitude
MON_longitude = MON_location.longitude



print('Location of Vancouver', VAN_latitude , VAN_longitude)
print('Location of Toronto', TOR_latitude, TOR_longitude)
print('Location of Montreal', MON_latitude, MON_longitude)
# Out:
# Location of Vancouver 49.2608724 -123.1139529
# Location of Toronto 43.6534817 -79.3839347
# Location of Montreal 45.4972159 -73.6103642

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for coffee shops in a radius of 5kms from the centres of the cities

# %% [markdown]
# #### To have the same prerequisites for each city we will assume that the same search radius should give the same chances for each city. The radius is set as 5km.

# %%
search_query = 'Coffee Shop'
radius = 5000

# %% [markdown]
# #### For the different cities we will define an URL each

# %%
url_VAN = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VAN_latitude, VAN_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url_TOR = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, TOR_latitude, TOR_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url_MON = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, MON_latitude, MON_longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results_VAN = requests.get(url_VAN).json()
results_TOR = requests.get(url_TOR).json()
results_MON = requests.get(url_MON).json()

# %% [markdown]
# #### Get relevant part of JSON and transform it into a _pandas_ dataframe

# %%
# assign relevant part of JSON to venues
venues_VAN = results_VAN['response']['venues']
venues_TOR = results_TOR['response']['venues']
venues_MON = results_MON['response']['venues']
# tranform venues into a dataframe
df_VAN = json_normalize(venues_VAN)
df_TOR = json_normalize(venues_TOR)
df_MON = json_normalize(venues_MON)
df_MON.tail()
# Out:
# <ipython-input-7-02958583a0f8>:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_VAN = json_normalize(venues_VAN)
# <ipython-input-7-02958583a0f8>:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_TOR = json_normalize(venues_TOR)
# <ipython-input-7-02958583a0f8>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_MON = json_normalize(venues_MON)
#                           id                                   name  \
# 45  4d5ec6775c39b1f719cbef49                    Newline barber shop
# 46  5df7d5cbc02d880007f4899e  White Heron Coffee (Café Héron Blanc)
# 47  5116a97ee4b0805e14485f79                             Audio Shop
# 48  5b84fca2c0af57002ca69274                             Sushi Shop
# 49  5a590e4c0a464d6ac47a5982                          Dumpling Shop
#
#                                            categories    referralId  hasPerk  \
# 45  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...  v-1624979523    False
# 46  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1624979523    False
# 47  [{'id': '4bf58dd8d48988d122951735', 'name': 'E...  v-1624979523    False
# 48  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1624979523    False
# 49  [{'id': '4bf58dd8d48988d108941735', 'name': 'D...  v-1624979523    False
#
#     location.lat  location.lng  \
# 45     45.497227    -73.643935
# 46     45.515212    -73.571554
# 47     45.497722    -73.575186
# 48     45.473220    -73.600918
# 49     45.474707    -73.623587
#
#                               location.labeledLatLngs  location.distance  \
# 45  [{'label': 'display', 'lat': 45.497227, 'lng':...               2619
# 46  [{'label': 'display', 'lat': 45.515212, 'lng':...               3630
# 47  [{'label': 'display', 'lat': 45.49772221935615...               2745
# 48  [{'label': 'display', 'lat': 45.47322, 'lng': ...               2771
# 49  [{'label': 'display', 'lat': 45.474707, 'lng':...               2709
#
#    location.cc location.city location.state location.country  \
# 45          CA       ontreal             QC           Canada
# 46          CA      Montréal             QC           Canada
# 47          CA      Montréal             QC           Canada
# 48          CA      Montréal             QC           Canada
# 49          CA      Montréal             QC           Canada
#
#                             location.formattedAddress  \
# 45          [Victoria (Mckenzie), ontreal QC, Canada]
# 46  [131 rue Prince-Arthur Est, Montréal QC H3S 1B...
# 47     [1193 Rue de la Montagne, Montréal QC, Canada]
# 48   [1001 Boul Decarie, Montréal QC H4A 3J1, Canada]
# 49  [5674 Av de Monkland, Montréal QC H4A 1E4, Can...
#
#              location.address location.postalCode location.crossStreet  \
# 45                   Victoria                 NaN             Mckenzie
# 46  131 rue Prince-Arthur Est             H3S 1B6                  NaN
# 47    1193 Rue de la Montagne                 NaN                  NaN
# 48          1001 Boul Decarie             H4A 3J1                  NaN
# 49        5674 Av de Monkland             H4A 1E4                  NaN
#
#    venuePage.id
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN

# %% [markdown]
# To have everything nice and visible in one dataframe we will concatenate these together

# %%
frames = [df_VAN, df_TOR, df_MON]
df_complete = pd.concat(frames)
df_complete.shape
# Out:
# (150, 19)

# %% [markdown]
# #### Define information of interest and filter dataframe.
# Now the data is filtered according to the categories.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_complete.columns if col.startswith('location.')] + ['id']
df = df_complete.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df['categories'] = df.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df.columns = [column.split('.')[-1] for column in df.columns]

df
# Out:
#                                      name           categories  \
# 0                     Laura's Coffee Shop                Diner
# 1                      7 Days Coffee Shop                 Café
# 2             The Taste & See Coffee Shop          Coffee Shop
# 3                   Eclettico Coffee Shop                 Café
# 4                Delicatessen Coffee Shop       Sandwich Place
# ..                                    ...                  ...
# 45                    Newline barber shop   Salon / Barbershop
# 46  White Heron Coffee (Café Héron Blanc)          Coffee Shop
# 47                             Audio Shop    Electronics Store
# 48                             Sushi Shop           Restaurant
# 49                          Dumpling Shop  Dumpling Restaurant
#
#                       address       crossStreet        lat         lng  \
# 0           1945 Manitoba St.       at 4th Ave.  49.267427 -123.106913
# 1              920 Beatty St.               NaN  49.275102 -123.117491
# 2   1628 West 1st Avenue #128               NaN  49.270256 -123.141433
# 3                         NaN               NaN  49.247820 -123.089950
# 4                         NaN  Davie at Burrard  49.278508 -123.129527
# ..                        ...               ...        ...         ...
# 45                   Victoria          Mckenzie  45.497227  -73.643935
# 46  131 rue Prince-Arthur Est               NaN  45.515212  -73.571554
# 47    1193 Rue de la Montagne               NaN  45.497722  -73.575186
# 48          1001 Boul Decarie               NaN  45.473220  -73.600918
# 49        5674 Av de Monkland               NaN  45.474707  -73.623587
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 49.267427, 'lng':...       891    V5Y 3A1
# 1   [{'label': 'display', 'lat': 49.275102, 'lng':...      1604        NaN
# 2   [{'label': 'display', 'lat': 49.270256, 'lng':...      2252        NaN
# 3   [{'label': 'display', 'lat': 49.24782, 'lng': ...      2269    V5V 4E8
# 4   [{'label': 'display', 'lat': 49.27850795147412...      2265        NaN
# ..                                                ...       ...        ...
# 45  [{'label': 'display', 'lat': 45.497227, 'lng':...      2619        NaN
# 46  [{'label': 'display', 'lat': 45.515212, 'lng':...      3630    H3S 1B6
# 47  [{'label': 'display', 'lat': 45.49772221935615...      2745        NaN
# 48  [{'label': 'display', 'lat': 45.47322, 'lng': ...      2771    H4A 3J1
# 49  [{'label': 'display', 'lat': 45.474707, 'lng':...      2709    H4A 1E4
#
#     cc       city state country  \
# 0   CA  Vancouver    BC  Canada
# 1   CA        NaN   NaN  Canada
# 2   CA  Vancouver    BC  Canada
# 3   CA  Vancouver    BC  Canada
# 4   CA  Vancouver    BC  Canada
# ..  ..        ...   ...     ...
# 45  CA    ontreal    QC  Canada
# 46  CA   Montréal    QC  Canada
# 47  CA   Montréal    QC  Canada
# 48  CA   Montréal    QC  Canada
# 49  CA   Montréal    QC  Canada
#
#                                      formattedAddress neighborhood  \
# 0   [1945 Manitoba St. (at 4th Ave.), Vancouver BC...          NaN
# 1                            [920 Beatty St., Canada]          NaN
# 2   [1628 West 1st Avenue #128, Vancouver BC, Canada]          NaN
# 3                      [Vancouver BC V5V 4E8, Canada]          NaN
# 4            [Davie at Burrard, Vancouver BC, Canada]          NaN
# ..                                                ...          ...
# 45          [Victoria (Mckenzie), ontreal QC, Canada]          NaN
# 46  [131 rue Prince-Arthur Est, Montréal QC H3S 1B...          NaN
# 47     [1193 Rue de la Montagne, Montréal QC, Canada]          NaN
# 48   [1001 Boul Decarie, Montréal QC H4A 3J1, Canada]          NaN
# 49  [5674 Av de Monkland, Montréal QC H4A 1E4, Can...          NaN
#
#                           id
# 0   4c48639e417b20a19bbfe0a9
# 1   57196f28498e2aeaefab44b2
# 2   586453fa0037eb3be739c864
# 3   5cca5b711fa763002ca67636
# 4   4eda85d546907c1b42d3711e
# ..                       ...
# 45  4d5ec6775c39b1f719cbef49
# 46  5df7d5cbc02d880007f4899e
# 47  5116a97ee4b0805e14485f79
# 48  5b84fca2c0af57002ca69274
# 49  5a590e4c0a464d6ac47a5982
#
# [150 rows x 16 columns]

# %% [markdown]
# #### Looking at the data it seems like there are also a lot of restaurants, sushi places, etc. that have been added. We would however be only looking for pure coffee shops. Thus we will have to clean the dataframe and remove everything that is not a coffee shop or café

# %% [markdown]
# #### Let's visualize the Coffee Shops that are in the cities. This only shows the data not yet an evaluation.

# %%
df.name
# Out:
# 0                       Laura's Coffee Shop
# 1                        7 Days Coffee Shop
# 2               The Taste & See Coffee Shop
# 3                     Eclettico Coffee Shop
# 4                  Delicatessen Coffee Shop
#                       ...
# 45                      Newline barber shop
# 46    White Heron Coffee (Café Héron Blanc)
# 47                               Audio Shop
# 48                               Sushi Shop
# 49                            Dumpling Shop
# Name: name, Length: 150, dtype: object

# %%
venues_map = folium.Map(location=[TOR_latitude, TOR_longitude], zoom_start=3) # generate map centred aroun Toronto

# add a red circle marker to represent the different cities
folium.CircleMarker(
    [TOR_latitude, TOR_longitude],
    radius=10,
    color='red',
    popup='Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

folium.CircleMarker(
    [VAN_latitude, VAN_longitude],
    radius=10,
    color='red',
    popup='Vancouver',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

folium.CircleMarker(
    [MON_latitude, MON_longitude],
    radius=10,
    color='red',
    popup='Montreal',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Coffee shops as blue circle markers
for lat, lng, label in zip(df.lat, df.lng, df.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_27a2359d80114691a3e5c1d58db54597%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_27a2359d80114691a3e5c1d58db54597%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_27a2359d80114691a3e5c1d58db54597%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_27a2359d80114691a3e5c1d58db54597%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# # Methodology
#
# With this data we will have a look at which city as the highest density of coffee shops. First of all we will filter for pure coffee shops or similar. This means that no restaurants, sushi places, etc. will be included in the dataframe.
#
# After cleaning the data we will analyze the amount of coffee shops near the centre of the city using a folium map. A simple map showing the amount will suffice in showing which city has the highest density. This will lead to the city selection.
#
# Considering that the coffee has to be distributed we will go one step further and cluster the city into n amounts. For the cluster we will consider that per week each coffee shop has to receive fresh coffee once. The coffee is distributed via bike and 8 coffee shops can be supplied per day as a first estimate. The clusters should show the area the bike has to supply.

# %% [markdown]
# # Analysis
#
# As we saw in the earlier description of the dataframe we will need to concentrate on the coffee shops. Everything that is a restaurant, sushi place or similar is not what is needed by the customer and will thus be removed from the dataframe. This we do with the following code.

# %%
df_coffee= df[df["name"].str.contains("Coffee|Café")==True]
df_coffee
# Out:
#                                      name      categories  \
# 0                     Laura's Coffee Shop           Diner
# 1                      7 Days Coffee Shop            Café
# 2             The Taste & See Coffee Shop     Coffee Shop
# 3                   Eclettico Coffee Shop            Café
# 4                Delicatessen Coffee Shop  Sandwich Place
# ..                                    ...             ...
# 4                            Coffee Depot            Café
# 8                         Dispatch Coffee            Café
# 21                        Dispatch Coffee            Café
# 30                        Dispatch Coffee            Café
# 46  White Heron Coffee (Café Héron Blanc)     Coffee Shop
#
#                          address       crossStreet        lat         lng  \
# 0              1945 Manitoba St.       at 4th Ave.  49.267427 -123.106913
# 1                 920 Beatty St.               NaN  49.275102 -123.117491
# 2      1628 West 1st Avenue #128               NaN  49.270256 -123.141433
# 3                            NaN               NaN  49.247820 -123.089950
# 4                            NaN  Davie at Burrard  49.278508 -123.129527
# ..                           ...               ...        ...         ...
# 4                            NaN               NaN  45.502210  -73.566780
# 8                3480 University               NaN  45.506021  -73.576323
# 21  4021 Boulevard Saint-Laurent       coin Duluth  45.516953  -73.579360
# 30                267 St-Zotique               NaN  45.528903  -73.616104
# 46     131 rue Prince-Arthur Est               NaN  45.515212  -73.571554
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 49.267427, 'lng':...       891    V5Y 3A1
# 1   [{'label': 'display', 'lat': 49.275102, 'lng':...      1604        NaN
# 2   [{'label': 'display', 'lat': 49.270256, 'lng':...      2252        NaN
# 3   [{'label': 'display', 'lat': 49.24782, 'lng': ...      2269    V5V 4E8
# 4   [{'label': 'display', 'lat': 49.27850795147412...      2265        NaN
# ..                                                ...       ...        ...
# 4   [{'label': 'display', 'lat': 45.50221, 'lng': ...      3445    H3B 3C1
# 8   [{'label': 'display', 'lat': 45.5060208804647,...      2831    H3A 0E9
# 21  [{'label': 'display', 'lat': 45.51695299024677...      3267    H2W 1Y4
# 30  [{'label': 'display', 'lat': 45.52890273538131...      3555    H2V 1A3
# 46  [{'label': 'display', 'lat': 45.515212, 'lng':...      3630    H3S 1B6
#
#     cc       city state country  \
# 0   CA  Vancouver    BC  Canada
# 1   CA        NaN   NaN  Canada
# 2   CA  Vancouver    BC  Canada
# 3   CA  Vancouver    BC  Canada
# 4   CA  Vancouver    BC  Canada
# ..  ..        ...   ...     ...
# 4   CA   Montréal    QC  Canada
# 8   CA   Montréal    QC  Canada
# 21  CA   Montréal    QC  Canada
# 30  CA   Montréal    QC  Canada
# 46  CA   Montréal    QC  Canada
#
#                                      formattedAddress neighborhood  \
# 0   [1945 Manitoba St. (at 4th Ave.), Vancouver BC...          NaN
# 1                            [920 Beatty St., Canada]          NaN
# 2   [1628 West 1st Avenue #128, Vancouver BC, Canada]          NaN
# 3                      [Vancouver BC V5V 4E8, Canada]          NaN
# 4            [Davie at Burrard, Vancouver BC, Canada]          NaN
# ..                                                ...          ...
# 4                       [Montréal QC H3B 3C1, Canada]          NaN
# 8      [3480 University, Montréal QC H3A 0E9, Canada]          NaN
# 21  [4021 Boulevard Saint-Laurent (coin Duluth), M...          NaN
# 30      [267 St-Zotique, Montréal QC H2V 1A3, Canada]          NaN
# 46  [131 rue Prince-Arthur Est, Montréal QC H3S 1B...          NaN
#
#                           id
# 0   4c48639e417b20a19bbfe0a9
# 1   57196f28498e2aeaefab44b2
# 2   586453fa0037eb3be739c864
# 3   5cca5b711fa763002ca67636
# 4   4eda85d546907c1b42d3711e
# ..                       ...
# 4   5783d19b498e6150d6db1420
# 8   54bff6d6498ecc37dcaf4764
# 21  57afa453498eb17ed0d8e5c3
# 30  544275ed498e539191256396
# 46  5df7d5cbc02d880007f4899e
#
# [94 rows x 16 columns]

# %% [markdown]
# This seems to be a bit more focused on the coffee aspect. Now we will create a marker map to easily see which city has the most potential customers. The amount of coffee shops in the central part (radius 5km) of the city will be our focus. For this we will use a folium map where the marker bubbles will show the amount of coffee shops.

# %%
from folium import plugins
from folium.plugins import MarkerCluster

map_canada = folium.Map(location=[TOR_latitude, TOR_longitude], zoom_start=3)

# instantiate a mark cluster object for the incidents in the dataframe
shops = MarkerCluster().add_to(map_canada)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_coffee.lat, df_coffee.lng, df_coffee.name):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(shops)

# display map
map_canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d4e70cb4aac34f2788d97731b4959237%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d4e70cb4aac34f2788d97731b4959237%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# We have to zoom in to see that Toronto has the most coffee shops in a radius of 5km closely followed by Vancouver and Montreal having only a third the amount in downtown. With this information we will focus on Toronto. The next step is to cluster the city into different areas, to allow for a normalized distribution of the coffee. Considering that the aim is to deliver the coffee by bike, we will need an even distribution in area. This means we will cluster the coffee shops into areas and not into the amount of coffee shops. Thus the area will be the same not the amount of coffee shops. These clusters are then the delivery areas for a specific day of the week. First we will create a dataset that only inlcudes the Toronto coffeeshops.

# %%
df_coffeeTOR= df_coffee[df_coffee["city"].str.contains("Toronto")==True]
df_coffeeTOR
# Out:
#                                         name   categories  \
# 0        Super Jet International Coffee Shop  Coffee Shop
# 1   Bluestone Lane Queen Station Coffee Shop         Café
# 2                 GRIP 6th Floor Coffee Shop  Coffee Shop
# 4                           Luis Coffee Shop  Coffee Shop
# 5            John Ford's Classic Coffee Shop  Coffee Shop
# 6                        Buro 53 Coffee Shop  Coffee Shop
# 7                                Coffee Shop         None
# 8                 First And Last Coffee Shop  Coffee Shop
# 9                  Green Rooster Coffee Shop  Coffee Shop
# 10                   First Break Coffee Shop  Coffee Shop
# 12                           Hub Coffee Shop  Coffee Shop
# 14                       Jason's Coffee Shop         Café
# 15                            Jetfuel Coffee  Coffee Shop
# 16                           HotBlack Coffee  Coffee Shop
# 17                    Timothy's World Coffee  Coffee Shop
# 18                    Timothy's World Coffee  Coffee Shop
# 19                             Coffee office         None
# 21                    Timothy's World Coffee  Coffee Shop
# 22               Sam James Coffee Bar (SJCB)  Coffee Shop
# 23                    Treats Coffee Emporium  Coffee Shop
# 24               Sam James Coffee Bar (SJCB)         Café
# 25                    Timothy's World Coffee  Coffee Shop
# 26                    Timothy's World Coffee  Coffee Shop
# 28                    Timothy's World Coffee  Coffee Shop
# 29                           Balzac's Coffee  Coffee Shop
# 30                         Fahrenheit Coffee  Coffee Shop
# 31                      Rooster Coffee House  Coffee Shop
# 32              Coffee Culture Cafe & Eatery  Coffee Shop
# 33                    Timothy's World Coffee  Coffee Shop
# 34                    Timothy's World Coffee  Coffee Shop
# 35                     Second Cup Coffee Co.  Coffee Shop
# 37                         Fahrenheit Coffee  Coffee Shop
# 39                     Pilot Coffee Roasters  Coffee Shop
# 41                           Balzac's Coffee         Café
# 42                             T.A.N. Coffee  Coffee Shop
# 45                    Timothy's World Coffee  Coffee Shop
# 46                           Balzac's Coffee  Coffee Shop
# 48                        M Square Coffee Co  Coffee Shop
#
#                             address                        crossStreet  \
# 0                   267 College St.                        Spadina Ave
# 1               2 Queen Street East                                NaN
# 2                      179 John St.                       at Queen St.
# 4                    235 Augusta St                  Baldwin & Augusta
# 5                        1 Yonge St              Yonge and Queens Quay
# 6                     53 Bloor St E                              Yonge
# 7                        1881 Yonge                                NaN
# 8                 346 Dupont Street                             Kendal
# 9                         Broadview                                NaN
# 10                       284 carlaw                    carlaw & dundas
# 12               983 Dovercourt Rd.                         Hallam St.
# 14                              NaN                                NaN
# 15               519 Parliament St.          btwn Carlton & Winchester
# 16            245 Queen Street West                   at St Patrick St
# 17  483 Bay St, Bell Trinity Square                Bell Trinity Square
# 18            427 University Avenue                                NaN
# 19           350 Bay St - 7th Floor                                NaN
# 21                      401 Bay St.                  at Richmond St. W
# 22                15 Toronto Street                                NaN
# 23              Bell Trinity Square                                NaN
# 24                   150 King St. W                        in the PATH
# 25               425 University Ave                             Dundas
# 26                 30 Adelaide St E                                NaN
# 28                            Yonge                             Dundas
# 29                  122 Bond Street                       at Gould St.
# 30                   120 Lombard St                       at Jarvis St
# 31                    568 Jarvis St                    At Charles St E
# 32                  409 College St.                  at Lippincott St.
# 33        66 Wellington Street West                TD Center Concourse
# 34                       801 Bay St                      at College St
# 35                   200 Front St W                    in Simcoe Place
# 37                529 Richmond St W                                NaN
# 39                    65 Front St W              btwn Bay St & York St
# 41                 10 Market Street  btwn The Esplanade & Front St. E.
# 42                    37 Baldwin St                           Henry St
# 45                     444 Yonge St                    in College Park
# 46                     7 Station St                         at SkyWalk
# 48             C24 - 123 Queen St W                                NaN
#
#           lat        lng                                     labeledLatLngs  \
# 0   43.657971 -79.399795  [{'label': 'display', 'lat': 43.657971, 'lng':...
# 1   43.652568 -79.379047  [{'label': 'display', 'lat': 43.6525684, 'lng'...
# 2   43.651035 -79.391256  [{'label': 'display', 'lat': 43.65103493678703...
# 4   43.654575 -79.402006  [{'label': 'display', 'lat': 43.654575, 'lng':...
# 5   43.641914 -79.374590  [{'label': 'display', 'lat': 43.64191404782495...
# 6   43.670532 -79.385293  [{'label': 'display', 'lat': 43.67053207847662...
# 7   43.638259 -79.425053  [{'label': 'display', 'lat': 43.63825857639313...
# 8   43.674320 -79.409450  [{'label': 'display', 'lat': 43.67432, 'lng': ...
# 9   43.669489 -79.353454  [{'label': 'display', 'lat': 43.669489, 'lng':...
# 10  43.663456 -79.341063  [{'label': 'display', 'lat': 43.66345609968515...
# 12  43.666932 -79.431510  [{'label': 'display', 'lat': 43.66693153385268...
# 14  43.640335 -79.438123  [{'label': 'display', 'lat': 43.640335, 'lng':...
# 15  43.665295 -79.368335  [{'label': 'display', 'lat': 43.66529519392083...
# 16  43.650364 -79.388669  [{'label': 'display', 'lat': 43.65036434800487...
# 17  43.653436 -79.382314  [{'label': 'display', 'lat': 43.653436, 'lng':...
# 18  43.654053 -79.388090  [{'label': 'display', 'lat': 43.65405317976302...
# 19  43.649498 -79.386479  [{'label': 'display', 'lat': 43.649498, 'lng':...
# 21  43.652135 -79.381172  [{'label': 'display', 'lat': 43.65213455850074...
# 22  43.650319 -79.376217  [{'label': 'display', 'lat': 43.65031871629752...
# 23  43.653117 -79.382310  [{'label': 'display', 'lat': 43.65311707897502...
# 24  43.647881 -79.384332  [{'label': 'display', 'lat': 43.64788137014028...
# 25  43.654270 -79.387448  [{'label': 'display', 'lat': 43.65427, 'lng': ...
# 26  43.650948 -79.376825  [{'label': 'display', 'lat': 43.650948, 'lng':...
# 28  43.656700 -79.379941  [{'label': 'display', 'lat': 43.65669995833159...
# 29  43.657854 -79.379200  [{'label': 'display', 'lat': 43.65785440672277...
# 30  43.652384 -79.372719  [{'label': 'display', 'lat': 43.65238358726612...
# 31  43.669654 -79.379871  [{'label': 'display', 'lat': 43.66965378571954...
# 32  43.656705 -79.406535  [{'label': 'display', 'lat': 43.65670534038625...
# 33  43.647130 -79.380776  [{'label': 'display', 'lat': 43.64713049355658...
# 34  43.660714 -79.385491  [{'label': 'display', 'lat': 43.66071353922905...
# 35  43.645009 -79.385812  [{'label': 'display', 'lat': 43.64500941272016...
# 37  43.647037 -79.400876  [{'label': 'display', 'lat': 43.64703669923361...
# 39  43.645018 -79.380415  [{'label': 'display', 'lat': 43.64501814464698...
# 41  43.648457 -79.371790  [{'label': 'display', 'lat': 43.64845650131932...
# 42  43.656029 -79.393534  [{'label': 'display', 'lat': 43.65602860741956...
# 45  43.660467 -79.384654  [{'label': 'display', 'lat': 43.66046739684086...
# 46  43.644373 -79.383065  [{'label': 'display', 'lat': 43.64437258414836...
# 48  43.651218 -79.383555  [{'label': 'display', 'lat': 43.65121797253777...
#
#     distance postalCode  cc     city state country  \
# 0       1371    M5T 1R5  CA  Toronto    ON  Canada
# 1        406    M5C 3G5  CA  Toronto    ON  Canada
# 2        649    M5T 1X4  CA  Toronto    ON  Canada
# 4       1460    M5T 1M1  CA  Toronto    ON  Canada
# 5       1491    M5J 2S7  CA  Toronto    ON  Canada
# 6       1901    M4W 1A9  CA  Toronto    ON  Canada
# 7       3720        NaN  CA  Toronto    ON  Canada
# 8       3098    M5R 1V9  CA  Toronto    ON  Canada
# 9       3033        NaN  CA  Toronto    ON  Canada
# 10      3626     M4M3l1  CA  Toronto    ON  Canada
# 12      4113        NaN  CA  Toronto    ON  Canada
# 14      4603        NaN  CA  Toronto    ON  Canada
# 15      1818    M4X 1P3  CA  Toronto    ON  Canada
# 16       515    M5V 1Z4  CA  Toronto    ON  Canada
# 17       130    M5G 2C9  CA  Toronto    ON  Canada
# 18       340        NaN  CA  Toronto    ON  Canada
# 19       488        NaN  CA  Toronto    ON  Canada
# 21       268    M5H 2Y4  CA  Toronto    ON  Canada
# 22       714        NaN  CA  Toronto    ON  Canada
# 23       137        NaN  CA  Toronto    ON  Canada
# 24       624    M5H 4B6  CA  Toronto    ON  Canada
# 25       296    M5G 1T6  CA  Toronto    ON  Canada
# 26       638    M5C 3G8  CA  Toronto    ON  Canada
# 28       481    M5B 2G9  CA  Toronto    ON  Canada
# 29       618    M5B 1X8  CA  Toronto    ON  Canada
# 30       911    M5C 3H5  CA  Toronto    ON  Canada
# 31      1829    M4Y 1N6  CA  Toronto    ON  Canada
# 32      1855        NaN  CA  Toronto    ON  Canada
# 33       751    M5K 1A1  CA  Toronto    ON  Canada
# 34       814    M5S 1Y9  CA  Toronto    ON  Canada
# 35       955    M5V 3K2  CA  Toronto    ON  Canada
# 37      1541        NaN  CA  Toronto    ON  Canada
# 39       983    M5J 1E6  CA  Toronto    ON  Canada
# 41      1126    M5E 1M6  CA  Toronto    ON  Canada
# 42       823        NaN  CA  Toronto    ON  Canada
# 45       779    M5B 2H4  CA  Toronto    ON  Canada
# 46      1016    M5J 1C3  CA  Toronto    ON  Canada
# 48       253        NaN  CA  Toronto    ON  Canada
#
#                                      formattedAddress            neighborhood  \
# 0   [267 College St. (Spadina Ave), Toronto ON M5T...                     NaN
# 1   [2 Queen Street East, Toronto ON M5C 3G5, Canada]                     NaN
# 2   [179 John St. (at Queen St.), Toronto ON M5T 1...                     NaN
# 4   [235 Augusta St (Baldwin & Augusta), Toronto O...                     NaN
# 5   [1 Yonge St (Yonge and Queens Quay), Toronto O...                     NaN
# 6   [53 Bloor St E (Yonge), Toronto ON M4W 1A9, Ca...                     NaN
# 7                    [1881 Yonge, Toronto ON, Canada]                     NaN
# 8   [346 Dupont Street (Kendal), Toronto ON M5R 1V...                     NaN
# 9                     [Broadview, Toronto ON, Canada]                     NaN
# 10  [284 carlaw (carlaw & dundas), Toronto ON M4M3...                     NaN
# 12  [983 Dovercourt Rd. (Hallam St.), Toronto ON, ...                     NaN
# 14                               [Toronto ON, Canada]                     NaN
# 15  [519 Parliament St. (btwn Carlton & Winchester...             Cabbagetown
# 16  [245 Queen Street West (at St Patrick St), Tor...  Entertainment District
# 17  [483 Bay St, Bell Trinity Square (Bell Trinity...                     NaN
# 18        [427 University Avenue, Toronto ON, Canada]                     NaN
# 19       [350 Bay St - 7th Floor, Toronto ON, Canada]                     NaN
# 21  [401 Bay St. (at Richmond St. W), Toronto ON M...                     NaN
# 22            [15 Toronto Street, Toronto ON, Canada]                     NaN
# 23          [Bell Trinity Square, Toronto ON, Canada]                     NaN
# 24  [150 King St. W (in the PATH), Toronto ON M5H ...                     NaN
# 25  [425 University Ave (Dundas), Toronto ON M5G 1...                     NaN
# 26     [30 Adelaide St E, Toronto ON M5C 3G8, Canada]                     NaN
# 28       [Yonge (Dundas), Toronto ON M5B 2G9, Canada]                     NaN
# 29  [122 Bond Street (at Gould St.), Toronto ON M5...                     NaN
# 30  [120 Lombard St (at Jarvis St), Toronto ON M5C...                     NaN
# 31  [568 Jarvis St (At Charles St E), Toronto ON M...                     NaN
# 32  [409 College St. (at Lippincott St.), Toronto ...                     NaN
# 33  [66 Wellington Street West (TD Center Concours...                     NaN
# 34  [801 Bay St (at College St), Toronto ON M5S 1Y...                     NaN
# 35  [200 Front St W (in Simcoe Place), Toronto ON ...                     NaN
# 37            [529 Richmond St W, Toronto ON, Canada]        Fashion District
# 39  [65 Front St W (btwn Bay St & York St), Toront...                     NaN
# 41  [10 Market Street (btwn The Esplanade & Front ...                     NaN
# 42     [37 Baldwin St (Henry St), Toronto ON, Canada]                     NaN
# 45  [444 Yonge St (in College Park), Toronto ON M5...                     NaN
# 46  [7 Station St (at SkyWalk), Toronto ON M5J 1C3...                     NaN
# 48         [C24 - 123 Queen St W, Toronto ON, Canada]                     NaN
#
#                           id
# 0   5ae32b6412c8f0002c2b03e7
# 1   5d493dc5735c2d0007bc3966
# 2   4c6bd9de69b4ef3b4d51474e
# 4   4ae92277f964a52072b421e3
# 5   4fe359f6d5fb75c734446273
# 6   590c8627a423623a3e5f534e
# 7   4ca5d17544a8224ba1eafc3f
# 8   5a77588666fc651c2d5560a7
# 9   4ba15904f964a52002af37e3
# 10  4b1c8f1ff964a5206a0824e3
# 12  528bc5a111d20301cc84ceaa
# 14  4cc45537c844721e6994e801
# 15  4ad79243f964a5204c0c21e3
# 16  59f784dd28122f14f9d5d63d
# 17  4b0aaa8ef964a520272623e3
# 18  4b44fc77f964a520cc0026e3
# 19  4baa31def964a52037523ae3
# 21  4baa9f6cf964a520817a3ae3
# 22  5553954a498e8e11bc49ecf2
# 23  509d036ee4b0912bf20c8abc
# 24  4fccaa8fe4b05a98df3d9417
# 25  53e8acc4498ee294fb100183
# 26  4d261e1e3c84b1f78bf70847
# 28  4ec514ec9911232436e364af
# 29  4fb13c20e4b011e6f93513c0
# 30  4fff1f96e4b042ae8acddca5
# 31  569e7814498e1a7f3e01bfe4
# 32  4afcbd58f964a520822522e3
# 33  4ba37627f964a520263f38e3
# 34  4b156e98f964a520cbac23e3
# 35  4b9e7808f964a52091e636e3
# 37  584593c2ebf0284fe7b103cb
# 39  563d2f2dcd10bcf27ae37c3b
# 41  536fd522498e09c6690800e2
# 42  4d8a7096d85f3704d05afedb
# 45  4bce5e21cc8cd13a7359c4cf
# 46  557f05ca498ec78ac7b29315
# 48  54132b3b498ee9ca9332e189

# %% [markdown]
# Now we will only focus on the positional data and remove all the columns that are not necessary. Then we will normalize this data to use it for the clustering method.

# %%
df_positiononly=df_coffeeTOR.drop(columns=['name', 'categories', 'address', 'crossStreet',
       'labeledLatLngs', 'distance', 'postalCode', 'cc', 'city', 'state',
       'country', 'formattedAddress', 'neighborhood', 'id'])
X = df_positiononly.values[:,1:]
X = np.nan_to_num(X)
cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset
# Out:
# array([[-0.71553454],
#        [ 0.43308681],
#        [-0.24282851],
#        [-0.83793738],
#        [ 0.67984008],
#        [ 0.0873081 ],
#        [-2.11383889],
#        [-1.25004354],
#        [ 1.84994256],
#        [ 2.53589366],
#        [-2.47128316],
#        [-2.83740516],
#        [ 1.02614314],
#        [-0.09959393],
#        [ 0.25222846],
#        [-0.06753569],
#        [ 0.02165052],
#        [ 0.31543687],
#        [ 0.58979088],
#        [ 0.25245296],
#        [ 0.14053637],
#        [-0.03199414],
#        [ 0.55610416],
#        [ 0.3836229 ],
#        [ 0.42463257],
#        [ 0.78341367],
#        [ 0.387499  ],
#        [-1.08869107],
#        [ 0.33735371],
#        [ 0.07633275],
#        [ 0.05860363],
#        [-0.77536842],
#        [ 0.35735355],
#        [ 0.83484951],
#        [-0.36894629],
#        [ 0.12270797],
#        [ 0.21066905],
#        [ 0.18354783]])

# %% [markdown]
# According to the assumption above we will need 5 clusters (for each day of the week).

# %%
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cluster_dataset)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 2, 0, 4, 2, 0, 1, 4, 3, 3], dtype=int32)

# %% [markdown]
# Now we visualize the data of the coffee shops that are closest together to show what areas could be delivered to in one day. For this we add a cluster label to the dataframe to allow for visualisation. Furthermore the name of the coffee shop is added as a label for identification. With this the distribution could start.

# %%
df_visual=df_coffeeTOR
df_visual.insert(0, 'Cluster Labels', kmeans.labels_)
df_visual


# create map
map_clusters = folium.Map(location=[TOR_latitude, TOR_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_visual['lat'], df_visual['lng'], df_visual['name'], df_visual['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_86b852c408fc4acaababad142b0e617d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_86b852c408fc4acaababad142b0e617d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_86b852c408fc4acaababad142b0e617d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_86b852c408fc4acaababad142b0e617d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Results and Discussion

# %% [markdown]
# The final map shows how the coffee could be distributed in the city of Toronto. Toronto was chosen as the basis for the coffee roastery as it had the greatest density of coffee shops in a 5km radius of the city centre compared to the cities Vancouver and Montreal. From the analysis this would have the highest chance of succeeding as the assumption is that the higher amount of coffee shops the higher the amount of potential for the need of coffee beans from a coffee roastery.
#
# The analysis does however have a few weaknesses in that a few points have to be evaluated in greater detail. The coffee shops that were evaluated are form a single database and maybe not all coffee shops were captured. For this other databases should be evaluated as well. A point that has to be considered is that Montreal shows far less coffee shops in comparison to the other two cities. The reasons for this should be looked to into as well and maybe the location of the city centre moved to find an area where the coffee shop density is higher.
#
# THe analysis focussed on three cities in Canada. It could be possible that further cities might have a higher density of coffee shops. This would however have to be discussed if a different city is an option.
#
# Furthermore it should be noted that the coffee shops probably already have there own coffee roastery distributor that supplies the coffee beans. This is difficult to evaluate but a first step would be to look into what coffee shops are part of a franchise and how many coffee roasteries are in the general area.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The analysis gave a first insight into which city is most probable to have a good customer base for a coffee roastery. Further analysis should be done to see where the coffee roastery could be physically based, i.e. in the city centre or further outside the city. This would have a large effect on the running costs.
#
# As the names of the coffee shops are available a survey should be done to see if there is a need for a different supplier of coffee beans. This is the proposed next step in finding the acceptance by the potential customers
